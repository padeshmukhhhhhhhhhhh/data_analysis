# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.xticks(np.arange(4,10))
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'])
plt.title("chart")
plt.xlabel("sepal")
plt.ylabel("petal")
plt.show()

# %%
m=[1,2,3,1,4,5,6,7]
bins=np.arange(0,8)

# %%
plt.hist(m,bins=bins,rwidth=0.5)
# Out:
# (array([0., 2., 1., 1., 1., 1., 2.]),
#  array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <BarContainer object of 7 artists>)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.pie(labels=df['Species'],x=df['Id'])
# Out:
# ([<matplotlib.patches.Wedge at 0x155713b0b10>,
#   <matplotlib.patches.Wedge at 0x155719b9790>,
#   <matplotlib.patches.Wedge at 0x155719ba6d0>,
#   <matplotlib.patches.Wedge at 0x155719bb550>,
#   <matplotlib.patches.Wedge at 0x155719cc590>,
#   <matplotlib.patches.Wedge at 0x155719cd590>,
#   <matplotlib.patches.Wedge at 0x155719ce650>,
#   <matplotlib.patches.Wedge at 0x155719cf590>,
#   <matplotlib.patches.Wedge at 0x155719cc690>,
#   <matplotlib.patches.Wedge at 0x155719dd350>,
#   <matplotlib.patches.Wedge at 0x155718c0a90>,
#   <matplotlib.patches.Wedge at 0x15570a7d210>,
#   <matplotlib.patches.Wedge at 0x15571893d90>,
#   <matplotlib.patches.Wedge at 0x15571894990>,
#   <matplotlib.patches.Wedge at 0x1557188d310>,
#   <matplotlib.patches.Wedge at 0x155719de090>,
#   <matplotlib.patches.Wedge at 0x155719df090>,
#   <matplotlib.patches.Wedge at 0x155719dff50>,
#   <matplotlib.patches.Wedge at 0x155719f4e90>,
#   <matplotlib.patches.Wedge at 0x155719f5d90>,
#   <matplotlib.patches.Wedge at 0x155719f6d90>,
#   <matplotlib.patches.Wedge at 0x155719f7710>,
#   <matplotlib.patches.Wedge at 0x15571a00d90>,
#   <matplotlib.patches.Wedge at 0x15571a01d90>,
#   <matplotlib.patches.Wedge at 0x15571a02d10>,
#   <matplotlib.patches.Wedge at 0x15571a03b10>,
#   <matplotlib.patches.Wedge at 0x15571a14b50>,
#   <matplotlib.patches.Wedge at 0x15571a15b10>,
#   <matplotlib.patches.Wedge at 0x15571a16a10>,
#   <matplotlib.patches.Wedge at 0x15571a179d0>,
#   <matplotlib.patches.Wedge at 0x15571a20690>,
#   <matplotlib.patches.Wedge at 0x15571a21950>,
#   <matplotlib.patches.Wedge at 0x15571a22950>,
#   <matplotlib.patches.Wedge at 0x15571a23750>,
#   <matplotlib.patches.Wedge at 0x15571a2c650>,
#   <matplotlib.patches.Wedge at 0x15571a2d310>,
#   <matplotlib.patches.Wedge at 0x15571a2e190>,
#   <matplotlib.patches.Wedge at 0x15571a2f250>,
#   <matplotlib.patches.Wedge at 0x15571a3c1d0>,
#   <matplotlib.patches.Wedge at 0x15571a3d0d0>,
#   <matplotlib.patches.Wedge at 0x15571a3e110>,
#   <matplotlib.patches.Wedge at 0x15571a3f010>,
#   <matplotlib.patches.Wedge at 0x15571a3ff50>,
#   <matplotlib.patches.Wedge at 0x15571a4ce10>,
#   <matplotlib.patches.Wedge at 0x15571a4ddd0>,
#   <matplotlib.patches.Wedge at 0x15571a4eb90>,
#   <matplotlib.patches.Wedge at 0x15571a4f550>,
#   <matplotlib.patches.Wedge at 0x15571a5ca50>,
#   <matplotlib.patches.Wedge at 0x15571a5d990>,
#   <matplotlib.patches.Wedge at 0x15571a5e9d0>,
#   <matplotlib.patches.Wedge at 0x15571a5f850>,
#   <matplotlib.patches.Wedge at 0x15571a70690>,
#   <matplotlib.patches.Wedge at 0x15571a71750>,
#   <matplotlib.patches.Wedge at 0x15571a72550>,
#   <matplotlib.patches.Wedge at 0x15571a73550>,
#   <matplotlib.patches.Wedge at 0x15571a7c450>,
#   <matplotlib.patches.Wedge at 0x15571a7d450>,
#   <matplotlib.patches.Wedge at 0x15571a7e190>,
#   <matplotlib.patches.Wedge at 0x15571a7f090>,
#   <matplotlib.patches.Wedge at 0x15571a7fed0>,
#   <matplotlib.patches.Wedge at 0x15571a90cd0>,
#   <matplotlib.patches.Wedge at 0x15571a91d50>,
#   <matplotlib.patches.Wedge at 0x15571a92cd0>,
#   <matplotlib.patches.Wedge at 0x15571a93a90>,
#   <matplotlib.patches.Wedge at 0x15571a9ca10>,
#   <matplotlib.patches.Wedge at 0x15571a9d890>,
#   <matplotlib.patches.Wedge at 0x15571a9e810>,
#   <matplotlib.patches.Wedge at 0x15571a9f650>,
#   <matplotlib.patches.Wedge at 0x15571ab0590>,
#   <matplotlib.patches.Wedge at 0x15571ab1310>,
#   <matplotlib.patches.Wedge at 0x15571ab2190>,
#   <matplotlib.patches.Wedge at 0x15571ab30d0>,
#   <matplotlib.patches.Wedge at 0x15571abc050>,
#   <matplotlib.patches.Wedge at 0x15571abce90>,
#   <matplotlib.patches.Wedge at 0x15571abdc10>,
#   <matplotlib.patches.Wedge at 0x15571abe990>,
#   <matplotlib.patches.Wedge at 0x15571abf990>,
#   <matplotlib.patches.Wedge at 0x15571acc650>,
#   <matplotlib.patches.Wedge at 0x15571acd7d0>,
#   <matplotlib.patches.Wedge at 0x15571ace610>,
#   <matplotlib.patches.Wedge at 0x15571acf450>,
#   <matplotlib.patches.Wedge at 0x15571adc3d0>,
#   <matplotlib.patches.Wedge at 0x15571add150>,
#   <matplotlib.patches.Wedge at 0x15571ade1d0>,
#   <matplotlib.patches.Wedge at 0x15571adf050>,
#   <matplotlib.patches.Wedge at 0x15571adfed0>,
#   <matplotlib.patches.Wedge at 0x15571af0d10>,
#   <matplotlib.patches.Wedge at 0x15571af1bd0>,
#   <matplotlib.patches.Wedge at 0x15571af2b50>,
#   <matplotlib.patches.Wedge at 0x15571af39d0>,
#   <matplotlib.patches.Wedge at 0x15571afc850>,
#   <matplotlib.patches.Wedge at 0x15571afd710>,
#   <matplotlib.patches.Wedge at 0x15571afdb90>,
#   <matplotlib.patches.Wedge at 0x15571aff310>,
#   <matplotlib.patches.Wedge at 0x15571b10310>,
#   <matplotlib.patches.Wedge at 0x15571b11150>,
#   <matplotlib.patches.Wedge at 0x15571b12150>,
#   <matplotlib.patches.Wedge at 0x15571b13050>,
#   <matplotlib.patches.Wedge at 0x15571b20090>,
#   <matplotlib.patches.Wedge at 0x15571b20cd0>,
#   <matplotlib.patches.Wedge at 0x15571b21cd0>,
#   <matplotlib.patches.Wedge at 0x155718bd210>,
#   <matplotlib.patches.Wedge at 0x15570c7e090>,
#   <matplotlib.patches.Wedge at 0x155718a1750>,
#   <matplotlib.patches.Wedge at 0x155718953d0>,
#   <matplotlib.patches.Wedge at 0x155718b7cd0>,
#   <matplotlib.patches.Wedge at 0x155711137d0>,
#   <matplotlib.patches.Wedge at 0x1557138ff50>,
#   <matplotlib.patches.Wedge at 0x15571882190>,
#   <matplotlib.patches.Wedge at 0x155718d3150>,
#   <matplotlib.patches.Wedge at 0x1557188e310>,
#   <matplotlib.patches.Wedge at 0x1557187acd0>,
#   <matplotlib.patches.Wedge at 0x1557187e950>,
#   <matplotlib.patches.Wedge at 0x155713e0410>,
#   <matplotlib.patches.Wedge at 0x1557130f490>,
#   <matplotlib.patches.Wedge at 0x155713d3a90>,
#   <matplotlib.patches.Wedge at 0x155713d2910>,
#   <matplotlib.patches.Wedge at 0x155713d1010>,
#   <matplotlib.patches.Wedge at 0x1557100e910>,
#   <matplotlib.patches.Wedge at 0x15570a6d450>,
#   <matplotlib.patches.Wedge at 0x15571010ed0>,
#   <matplotlib.patches.Wedge at 0x15571093590>,
#   <matplotlib.patches.Wedge at 0x15571090090>,
#   <matplotlib.patches.Wedge at 0x15571089350>,
#   <matplotlib.patches.Wedge at 0x15571088d10>,
#   <matplotlib.patches.Wedge at 0x15570ff2b10>,
#   <matplotlib.patches.Wedge at 0x15571014690>,
#   <matplotlib.patches.Wedge at 0x15571017b10>,
#   <matplotlib.patches.Wedge at 0x1557102e990>,
#   <matplotlib.patches.Wedge at 0x1557102f1d0>,
#   <matplotlib.patches.Wedge at 0x155710a9690>,
#   <matplotlib.patches.Wedge at 0x155710a1150>,
#   <matplotlib.patches.Wedge at 0x15571002510>,
#   <matplotlib.patches.Wedge at 0x15571004a50>,
#   <matplotlib.patches.Wedge at 0x15571004d50>,
#   <matplotlib.patches.Wedge at 0x1557108f790>,
#   <matplotlib.patches.Wedge at 0x155710331d0>,
#   <matplotlib.patches.Wedge at 0x1557101d950>,
#   <matplotlib.patches.Wedge at 0x1557101d350>,
#   <matplotlib.patches.Wedge at 0x15571096710>,
#   <matplotlib.patches.Wedge at 0x15571096090>,
#   <matplotlib.patches.Wedge at 0x155710276d0>,
#   <matplotlib.patches.Wedge at 0x15570ffe950>,
#   <matplotlib.patches.Wedge at 0x15570ffa350>,
#   <matplotlib.patches.Wedge at 0x15571037110>,
#   <matplotlib.patches.Wedge at 0x15570ac5d10>,
#   <matplotlib.patches.Wedge at 0x15570ac5e50>,
#   <matplotlib.patches.Wedge at 0x15570c73110>,
#   <matplotlib.patches.Wedge at 0x15570c70150>,
#   <matplotlib.patches.Wedge at 0x15570af4950>],
#  [Text(1.0999999576760673, 0.00030514365511604514, 'Iris-setosa'),
#   Text(1.0999993228171412, 0.0012205743856481999, 'Iris-setosa'),
#   Text(1.0999965717633315, 0.0027462900279656894, 'Iris-setosa'),
#   Text(1.0999891650913802, 0.0048822824138101475, 'Iris-setosa'),
#   Text(1.099973547648928, 0.00762853017502939, 'Iris-setosa'),
#   Text(1.0999451486416836, 0.010984988831347334, 'Iris-setosa'),
#   Text(1.0998983818062247, 0.014951578513605193, 'Iris-setosa'),
#   Text(1.099826645729183, 0.01952816796564491, 'Iris-setosa'),
#   Text(1.0997223243665335, 0.02471455623451589, 'Iris-setosa'),
#   Text(1.099576787824184, 0.03051045195092268, 'Iris-setosa'),
#   Text(1.0993803934924662, 0.03691544939927523, 'Iris-setosa'),
#   Text(1.0991224876487256, 0.043929001182333505, 'Iris-setosa'),
#   Text(1.098791407566746, 0.051550389498907855, 'Iris-setosa'),
#   Text(1.0983744843229182, 0.05977869343138774, 'Iris-setosa'),
#   Text(1.0978580464202097, 0.06861275326352335, 'Iris-setosa'),
#   Text(1.0972274242541373, 0.0780511336537228, 'Iris-setosa'),
#   Text(1.0964669557129432, 0.08809208267257009, 'Iris-setosa'),
#   Text(1.0955599929901103, 0.0987334885411719, 'Iris-setosa'),
#   Text(1.0944889107923677, 0.10997283370240504, 'Iris-setosa'),
#   Text(1.0932351161202771, 0.12180714626607174, 'Iris-setosa'),
#   Text(1.091779059759181, 0.13423294927609644, 'Iris-setosa'),
#   Text(1.0901002498589427, 0.14724620625833093, 'Iris-setosa'),
#   Text(1.088177267613769, 0.16084226511906521, 'Iris-setosa'),
#   Text(1.0859877852566584, 0.17501580006770365, 'Iris-setosa'),
#   Text(1.083508586553069, 0.1897607516473596, 'Iris-setosa'),
#   Text(1.0807155902802936, 0.20507026338578935, 'Iris-setosa'),
#   Text(1.0775838771237969, 0.22093661480806223, 'Iris-setosa'),
#   Text(1.0740877191044607, 0.23735115687305416, 'Iris-setosa'),
#   Text(1.0702006130963369, 0.2543042424503076, 'Iris-setosa'),
#   Text(1.065895318027833, 0.2717851559713019, 'Iris-setosa'),
#   Text(1.061143896151754, 0.28978204164488114, 'Iris-setosa'),
#   Text(1.0559177586441524, 0.308281830440767, 'Iris-setosa'),
#   Text(1.0501877157932644, 0.32727016606608983, 'Iris-setosa'),
#   Text(1.0439240320397773, 0.3467313301820503, 'Iris-setosa'),
#   Text(1.03709648585997, 0.36664816788973725, 'Iris-setosa'),
#   Text(1.0296744360594885, 0.3870020099761427, 'Iris-setosa'),
#   Text(1.0216268921657718, 0.40777259986873393, 'Iris-setosa'),
#   Text(1.012922591670068, 0.4289380179983968, 'Iris-setosa'),
#   Text(1.0035300831303882, 0.4504746077775264, 'Iris-setosa'),
#   Text(0.9934178155997715, 0.47235690282770165, 'Iris-setosa'),
#   Text(0.9825542345914076, 0.4945575558885876, 'Iris-setosa'),
#   Text(0.9709078843980126, 0.5170472705795629, 'Iris-setosa'),
#   Text(0.9584475188001083, 0.5397947329364341, 'Iris-setosa'),
#   Text(0.9451422166692837, 0.5627665504180869, 'Iris-setosa'),
#   Text(0.9309615057526981, 0.5859271924110275, 'Iris-setosa'),
#   Text(0.9158754950913585, 0.609238933006714, 'Iris-setosa'),
#   Text(0.8998550128031048, 0.6326618021764269, 'Iris-setosa'),
#   Text(0.8828717515507343, 0.6561535417215538, 'Iris-setosa'),
#   Text(0.8648984213154273, 0.6796695673679101, 'Iris-setosa'),
#   Text(0.8459089120055946, 0.7031629345958954, 'Iris-setosa'),
#   Text(0.825878461632473, 0.7265843148675728, 'Iris-versicolor'),
#   Text(0.8047838283364923, 0.7498819838134928, 'Iris-versicolor'),
#   Text(0.782603475538724, 0.7730018111716881, 'Iris-versicolor'),
#   Text(0.7593177609155718, 0.7958872646035761, 'Iris-versicolor'),
#   Text(0.7349091293694725, 0.818479426479007, 'Iris-versicolor'),
#   Text(0.7093623140816313, 0.8407170197877246, 'Iris-versicolor'),
#   Text(0.6826645456712476, 0.8625364444958076, 'Iris-versicolor'),
#   Text(0.6548057642106971, 0.8838718295977337, 'Iris-versicolor'),
#   Text(0.625778831720833, 0.9046551021080408, 'Iris-versicolor'),
#   Text(0.5955797560221672, 0.9248160650727127, 'Iris-versicolor'),
#   Text(0.564207914002827, 0.9442824946892635, 'Iris-versicolor'),
#   Text(0.5316662742230427, 0.9629802556926017, 'Iris-versicolor'),
#   Text(0.4979616232834901, 0.9808334322079727, 'Iris-versicolor'),
#   Text(0.4631047953199043, 0.9977644754909396, 'Iris-versicolor'),
#   Text(0.4271108978887179, 1.013694372532813, 'Iris-versicolor'),
#   Text(0.38999953264505277, 1.0285428355380444, 'Iris-versicolor'),
#   Text(0.35179501529527274, 1.0422285100751174, 'Iris-versicolor'),
#   Text(0.3125265937182515, 1.0546692032191265, 'Iris-versicolor'),
#   Text(0.2722286567167279, 1.065782134613921, 'Iris-versicolor'),
#   Text(0.23094092991013201, 1.0754842104337208, 'Iris-versicolor'),
#   Text(0.18870867104758876, 1.0836923167908192, 'Iris-versicolor'),
#   Text(0.14558284910443617, 1.0903236372961174, 'Iris-versicolor'),
#   Text(0.10162030654427805, 1.0952959934637976, 'Iris-versicolor'),
#   Text(0.05688390909218453, 1.0985282066867432, 'Iris-versicolor'),
#   Text(0.01144268105976482, 1.0999404825035601, 'Iris-versicolor'),
#   Text(-0.0346280823904506, 1.0994548175845884, 'Iris-versicolor'),
#   Text(-0.08124672995543848, 1.0969954279173402, 'Iris-versicolor'),
#   Text(-0.12832518366069318, 1.0924891977673965, 'Iris-versicolor'),
#   Text(-0.1757688999517986, 1.0858661491223192, 'Iris-versicolor'),
#   Text(-0.22347686314567927, 1.0770599294554448, 'Iris-versicolor'),
#   Text(-0.27134160719341954, 1.0660083171372032, 'Iris-versicolor'),
#   Text(-0.31924926831090056, 1.0526537439647259, 'Iris-versicolor'),
#   Text(-0.36707967727689733, 1.0369438319071527, 'Iris-versicolor'),
#   Text(-0.414706495049569, 1.0188319404905315, 'Iris-versicolor'),
#   Text(-0.46199738026803516, 0.9982777272009391, 'Iris-versicolor'),
#   Text(-0.5088142049387033, 0.9752477146102909, 'Iris-versicolor'),
#   Text(-0.5550133185388436, 0.9497158607944275, 'Iris-versicolor'),
#   Text(-0.6004458566325619, 0.9216641325628274, 'Iris-versicolor'),
#   Text(-0.6449580963885788, 0.8910830791249605, 'Iris-versicolor'),
#   Text(-0.688391867699465, 0.8579723984402077, 'Iris-versicolor'),
#   Text(-0.7305850144930681, 0.8223414963372356, 'Iris-versicolor'),
#   Text(-0.7713719139891865, 0.7842100294619161, 'Iris-versicolor'),
#   Text(-0.8105840494281827, 0.7436084311064591, 'Iris-versicolor'),
#   Text(-0.8480506311644249, 0.7005784231487726, 'Iris-versicolor'),
#   Text(-0.8835992879421449, 0.6551734872139857, 'Iris-versicolor'),
#   Text(-0.917056805208043, 0.6074593122354925, 'Iris-versicolor'),
#   Text(-0.9482499219423687, 0.557514202093805, 'Iris-versicolor'),
#   Text(-0.977006184308436, 0.5054294370365368, 'Iris-versicolor'),
#   Text(-1.003154847170291, 0.45130959728189957, 'Iris-versicolor'),
#   Text(-1.0265278377769502, 0.39527281498855904, 'Iris-versicolor'),
#   Text(-1.0469607636927711, 0.33745097316180567, 'Iris-virginica'),
#   Text(-1.064293965462603, 0.27798984708058644, 'Iris-virginica'),
#   Text(-1.07837362006115, 0.21704915470052116, 'Iris-virginica'),
#   Text(-1.089052879617082, 0.15480253679362557, 'Iris-virginica'),
#   Text(-1.0961930443794548, 0.09143746198415056, 'Iris-virginica'),
#   Text(-1.0996647692681252, 0.027155022196293913, 'Iris-virginica'),
#   Text(-1.0993492912635725, -0.03783035551354689, 'Iris-virginica'),
#   Text(-1.0951396746520432, -0.10329130168130017, 'Iris-virginica'),
#   Text(-1.086942065424298, -0.16898800670805378, 'Iris-virginica'),
#   Text(-1.0746769488313037, -0.23466882121543042, 'Iris-virginica'),
#   Text(-1.0582803979243858, -0.3000709905489098, 'Iris-virginica'),
#   Text(-1.0377053052088594, -0.3649214977791637, 'Iris-virginica'),
#   Text(-1.0129225913563173, -0.42893801873930826, 'Iris-virginica'),
#   Text(-0.9839223712149724, -0.4918300188303946, 'Iris-virginica'),
#   Text(-0.9507150726211676, -0.5532999644776132, 'Iris-virginica'),
#   Text(-0.9133325001276177, -0.6130446510741575, 'Iris-virginica'),
#   Text(-0.8718288172781672, -0.6707566722466146, 'Iris-virginica'),
#   Text(-0.8262814466567062, -0.7261260020897894, 'Iris-virginica'),
#   Text(-0.7767918783598079, -0.7788416897638707, 'Iris-virginica'),
#   Text(-0.7234863549110647, -0.8285936846594361, 'Iris-virginica'),
#   Text(-0.6665164385487635, -0.8750747608886184, 'Iris-virginica'),
#   Text(-0.6060594381550363, -0.9179825474502237, 'Iris-virginica'),
#   Text(-0.542318681502316, -0.9570216547673254, 'Iris-virginica'),
#   Text(-0.47552363352426014, -0.9919058795873151, 'Iris-virginica'),
#   Text(-0.4059298207476607, -1.0223604944576898, 'Iris-virginica'),
#   Text(-0.33381857328665776, -1.0481245918920423, 'Iris-virginica'),
#   Text(-0.25949657502709594, -1.0689534730516603, 'Iris-virginica'),
#   Text(-0.18329518377197723, -1.084621074664326, 'Iris-virginica'),
#   Text(-0.10556953832068551, -1.0949224048208883, 'Iris-virginica'),
#   Text(-0.02669744534433137, -1.099675973372196, 'Iris-virginica'),
#   Text(0.052921989928629266, -1.0987262001891072, 'Iris-virginica'),
#   Text(0.13286996292199293, -1.0919457738153064, 'Iris-virginica'),
#   Text(0.2127098182240423, -1.079237940970894, 'Iris-virginica'),
#   Text(0.2919891490590093, -1.0605387012418717, 'Iris-virginica'),
#   Text(0.37024213158840247, -1.0358188857116268, 'Iris-virginica'),
#   Text(0.44699212279798556, -1.0050860869381044, 'Iris-virginica'),
#   Text(0.521754487765954, -0.9683864179634528, 'Iris-virginica'),
#   Text(0.5940396498743553, -0.9258060781703441, 'Iris-virginica'),
#   Text(0.6633563792909725, -0.8774726856455258, 'Iris-virginica'),
#   Text(0.7292152787725269, -0.823556359458602, 'Iris-virginica'),
#   Text(0.79113245268841, -0.7642705295268298, 'Iris-virginica'),
#   Text(0.848633361847958, -0.6998724292030892, 'Iris-virginica'),
#   Text(0.9012568169493651, -0.6306632618936184, 'Iris-virginica'),
#   Text(0.9485590881159003, -0.5569880217318248, 'Iris-virginica'),
#   Text(0.9901181186091985, -0.47923492276938784, 'Iris-virginica'),
#   Text(1.0255377893309472, -0.3978344412619325, 'Iris-virginica'),
#   Text(1.0544522094560462, -0.3132579415964788, 'Iris-virginica'),
#   Text(1.0765299932379306, -0.2260158703700724, 'Iris-virginica'),
#   Text(1.0914784780589482, -0.13665552288188965, 'Iris-virginica'),
#   Text(1.0990478488341855, -0.045758343205908936, 'Iris-virginica')])

# %%
a=["ram","sham"]
b=[56,47]
plt.bar(x=b,labels=a,autopct="%0.1f%%")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 a=["ram","sham"]
#       2 b=[56,47]
# ----> 3 plt.bar(x=b,labels=a,autopct="%0.1f%%")
#       4 plt.legend()
#
# TypeError: bar() missing 1 required positional argument: 'height'
