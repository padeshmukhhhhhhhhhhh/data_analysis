# %%
import yfinance as yf
import talib

# %%
data=yf.Ticker("YESBANK.NS")

# %%
data
talib.get_function_groups()
# Out:
# {'Cycle Indicators': ['HT_DCPERIOD',
#   'HT_DCPHASE',
#   'HT_PHASOR',
#   'HT_SINE',
#   'HT_TRENDMODE'],
#  'Math Operators': ['ADD',
#   'DIV',
#   'MAX',
#   'MAXINDEX',
#   'MIN',
#   'MININDEX',
#   'MINMAX',
#   'MINMAXINDEX',
#   'MULT',
#   'SUB',
#   'SUM'],
#  'Math Transform': ['ACOS',
#   'ASIN',
#   'ATAN',
#   'CEIL',
#   'COS',
#   'COSH',
#   'EXP',
#   'FLOOR',
#   'LN',
#   'LOG10',
#   'SIN',
#   'SINH',
#   'SQRT',
#   'TAN',
#   'TANH'],
#  'Momentum Indicators': ['ADX',
#   'ADXR',
#   'APO',
#   'AROON',
#   'AROONOSC',
#   'BOP',
#   'CCI',
#   'CMO',
#   'DX',
#   'MACD',
#   'MACDEXT',
#   'MACDFIX',
#   'MFI',
#   'MINUS_DI',
#   'MINUS_DM',
#   'MOM',
#   'PLUS_DI',
#   'PLUS_DM',
#   'PPO',
#   'ROC',
#   'ROCP',
#   'ROCR',
#   'ROCR100',
#   'RSI',
#   'STOCH',
#   'STOCHF',
#   'STOCHRSI',
#   'TRIX',
#   'ULTOSC',
#   'WILLR'],
#  'Overlap Studies': ['BBANDS',
#   'DEMA',
#   'EMA',
#   'HT_TRENDLINE',
#   'KAMA',
#   'MA',
#   'MAMA',
#   'MAVP',
# ...

# %%
data.info
# Out:
# {'address1': 'YES BANK House',
#  'address2': 'Off Western Express Highway Santacruz East',
#  'city': 'Mumbai',
#  'zip': '400055',
#  'country': 'India',
#  'phone': '91 22 5091 9800',
#  'fax': '91 22 2619 2866',
#  'website': 'https://www.yesbank.in',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
# ...

# %%
data.history(period="6mo")
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                 Open       High        Low      Close  \
# Date
# 2023-07-31 00:00:00+05:30  16.950001  17.100000  16.900000  16.950001
# 2023-08-01 00:00:00+05:30  17.100000  17.200001  17.000000  17.100000
# 2023-08-02 00:00:00+05:30  17.049999  17.299999  16.850000  17.000000
# 2023-08-03 00:00:00+05:30  17.000000  17.100000  16.900000  17.000000
# 2023-08-04 00:00:00+05:30  17.049999  17.150000  16.900000  16.950001
# ...                              ...        ...        ...        ...
# 2024-01-23 00:00:00+05:30  25.450001  25.600000  23.900000  24.049999
# 2024-01-24 00:00:00+05:30  24.150000  24.799999  23.650000  24.700001
# ...

# %%
symbol="YESBANK.NS"
df=data.history(symbol, start="2023-1-30", end="2024-01-30", interval='1d')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
df
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-01-30 00:00:00+05:30  17.500000  17.900000  17.000000  17.100000
# 2023-01-31 00:00:00+05:30  17.100000  17.600000  16.750000  17.250000
# 2023-02-01 00:00:00+05:30  17.299999  17.549999  16.650000  16.900000
# 2023-02-02 00:00:00+05:30  16.850000  17.250000  16.700001  16.850000
# 2023-02-03 00:00:00+05:30  16.950001  17.150000  16.150000  16.450001
# ...                              ...        ...        ...        ...
# 2024-01-19 00:00:00+05:30  25.100000  25.549999  25.100000  25.150000
# 2024-01-23 00:00:00+05:30  25.450001  25.600000  23.900000  24.049999
# 2024-01-24 00:00:00+05:30  24.150000  24.799999  23.650000  24.700001
# 2024-01-25 00:00:00+05:30  24.799999  25.299999  24.700001  24.850000
# 2024-01-29 00:00:00+05:30  25.299999  25.500000  24.250000  24.350000
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
df["RSI"]=talib.RSI(df["Close"],timeperiod=14)

# %%
talib.help
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 talib.help
#
# AttributeError: module 'talib' has no attribute 'help'

# %%
df
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-01-30 00:00:00+05:30  17.500000  17.900000  17.000000  17.100000
# 2023-01-31 00:00:00+05:30  17.100000  17.600000  16.750000  17.250000
# 2023-02-01 00:00:00+05:30  17.299999  17.549999  16.650000  16.900000
# 2023-02-02 00:00:00+05:30  16.850000  17.250000  16.700001  16.850000
# 2023-02-03 00:00:00+05:30  16.950001  17.150000  16.150000  16.450001
# ...                              ...        ...        ...        ...
# 2024-01-22 00:00:00+05:30  25.150000  25.150000  25.150000  25.150000
# 2024-01-23 00:00:00+05:30  25.450001  25.600000  23.900000  24.049999
# 2024-01-24 00:00:00+05:30  24.150000  24.799999  23.650000  24.700001
# 2024-01-25 00:00:00+05:30  24.799999  25.299999  24.700001  24.850000
# 2024-01-29 00:00:00+05:30  25.299999  25.500000  24.250000  24.350000
#
#                               Volume  Dividends  Stock Splits        RSI
# Date
# ...

# %%
print(df["rsi"] )
# Out:
# 17.25

# %%
buy=[]
sell=[]
position=False
for i in range(14,len(df)):
    position=False
    if position==False and df["RSI"][i] < 30:
        print("buy")
        position=True
        buy.append(df["Close"])
    elif position==True and df["RSI"][i] > 70:
        print("sell")
        positon=False
        sell.append(df["Close"])
# Out:
# buy
# buy
# buy
# buy
# buy
# C:\Users\admin\AppData\Local\Temp\ipykernel_6136\2128093304.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if position==False and df["RSI"][i] < 30:

# %%
condition = (df['RSI'] < 30)
df[condition]
# Out:
#                                 Open       High    Low  Close     Volume  \
# Date
# 2023-10-25 00:00:00+05:30  16.400000  16.700001  15.85  16.00  156556497
# 2023-10-26 00:00:00+05:30  16.000000  16.049999  15.70  15.90  153370332
# 2023-10-27 00:00:00+05:30  15.950000  16.150000  15.90  15.95   74336446
# 2023-10-30 00:00:00+05:30  16.049999  16.100000  15.85  15.95  120388059
# 2023-10-31 00:00:00+05:30  16.100000  16.150000  15.90  15.95   52455781
#
#                            Dividends  Stock Splits        RSI
# Date
# 2023-10-25 00:00:00+05:30        0.0           0.0  29.153420
# 2023-10-26 00:00:00+05:30        0.0           0.0  28.101605
# 2023-10-27 00:00:00+05:30        0.0           0.0  29.471753
# 2023-10-30 00:00:00+05:30        0.0           0.0  29.471753
# 2023-10-31 00:00:00+05:30        0.0           0.0  29.471753

# %%
buy=[]
sell=[]
position=False
for i in range(14,len(df)):

    if position==False and df.iloc[i, df.columns.get_loc('RSI')] < 30:
        print("buy")
        position=True
        print(df.iloc[i, df.columns.get_loc('Close')])
        buy.append(df.iloc[i, df.columns.get_loc('Close')])
    elif position==True and df.iloc[i, df.columns.get_loc('RSI')] > 70:
        print("sell")
        position=False
        print(df.iloc[i, df.columns.get_loc('Close')])
        sell.append(df.iloc[i, df.columns.get_loc('Close')])
    else:
        pass
# Out:
# buy
# 16.0
# sell
# 18.350000381469727

# %%
print(buy)
# Out:
# [16.0]

# %%
buy=[]
sell=[]
position=False
for i in range(14,len(df)):
    position=False
    if position==False and df["RSI"][i] < 30:
        print("buy")
        position=True
        buy.append(df["Close"])
    elif position==True and df["RSI"][i] > 70:
        print("sell")
        position=False
        sell.append(df["Close"])
# Out:
# buy
# buy
# buy
# buy
# buy
# C:\Users\admin\AppData\Local\Temp\ipykernel_6136\1091826862.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if position==False and df["RSI"][i] < 30:

# %%
buy=[]
sell=[]
for i in range(14,len(df)):
    position=False
    if position==False and df["RSI"][i] < 30:
        print("buy")
        position=True
        buy.append(df["Close"])
    elif position==True and df["RSI"][i] > 70:
        print("sell")
        position=False
        sell.append(df["Close"])
# Out:
# buy
# buy
# buy
# buy
# buy
# C:\Users\admin\AppData\Local\Temp\ipykernel_6136\2842390942.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if position==False and df["RSI"][i] < 30:

# %%
print(sell)
# Out:
# []
